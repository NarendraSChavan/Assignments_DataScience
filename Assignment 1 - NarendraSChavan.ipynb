# %%
Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
n=int(input("enter a number:"))
if n<=1:
    print("It is not a prime number")
else:
    for i in range(2,n):
        if n%i==0:
                 print(f"{n} is not a prime Number")
                 break
    else:
        print(f"{n} is a prime number")
# Out:
# enter a number: 9
# 9 is not a prime Number

# %%
Exercise 2: Product of Random Numbers
Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
n = random.randint(1,100)
m = random.randint(1,100)
print("a =",n)
print("b =",m)
user = int(input("Enter the Product of the this Above 2 numbers i.e a * b :"))
if user == n*m:
    print("Your Answer is Correct, Nice!")
else:
    print("Your Answer is Wrong, Try Again!")
# Out:
# a = 27
# b = 55
# Enter the Product of the this Above 2 numbers i.e a * b : 182
# Your Answer is Wrong, Try Again!

# %%
Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
choice = input("Enter Choice (even or odd) to get squares of all even or odd numbers within the range of 100 to 200:")
match choice:
    case 'even':
        for i in range(100,201):
            if i%2==0:
                print(f"Even numbers Square {[i]} = ",i**2)
    case 'odd':
        for i in range(100,201):
            if i%2!=0:
                print(f"Odd numbers Square {[i]} = ",i**2)
    case default:
        print("Please Enter choice (even or odd)")
# Out:
# Enter Choice (even or odd) to get squares of all even or odd numbers within the range of 100 to 200: even
# Even numbers Square [100] =  10000
# Even numbers Square [102] =  10404
# Even numbers Square [104] =  10816
# Even numbers Square [106] =  11236
# Even numbers Square [108] =  11664
# Even numbers Square [110] =  12100
# Even numbers Square [112] =  12544
# Even numbers Square [114] =  12996
# Even numbers Square [116] =  13456
# Even numbers Square [118] =  13924
# Even numbers Square [120] =  14400
# Even numbers Square [122] =  14884
# Even numbers Square [124] =  15376
# Even numbers Square [126] =  15876
# Even numbers Square [128] =  16384
# Even numbers Square [130] =  16900
# Even numbers Square [132] =  17424
# Even numbers Square [134] =  17956
# Even numbers Square [136] =  18496
# Even numbers Square [138] =  19044
# Even numbers Square [140] =  19600
# Even numbers Square [142] =  20164
# Even numbers Square [144] =  20736
# Even numbers Square [146] =  21316
# ...

# %%
room_chr = int(input("How many days you stayed:"))
lab_tests = int(input("How many Lab tests you had done:"))
Med_chr = int(input("Enter your medicine Charges:"))
doc_fee = 1500
if room_chr>=1:
    charge = room_chr*2000
if lab_tests>=0:
    tests = lab_tests*300
Actual_bill = charge+tests+Med_chr+doc_fee
print("Actual Bill:",Actual_bill)

if Actual_bill>=10000:
    bill = Actual_bill*0.1
    print("Total Discount Bill is:",bill)
else:
    print("You didnot get Discount!")
print("Final Bill Amount:",Actual_bill - bill)
# Out:
# How many days you stayed: 3
# How many Lab tests you had done: 4
# Enter your medicine Charges: 2300
# Actual Bill: 11000
# Total Discount Bill is: 1100.0
# Final Bill Amount: 9900.0
